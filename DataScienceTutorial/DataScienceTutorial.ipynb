# %% [markdown]
# # DATA SCIENTIST (VERİ BİLİMCİSİ)
# **Bu derste, veri bilimcisi olmak için gereken nitelikler ve teknik bilgiler açıklanmaktadır.**
#
# Bir Veri Bilimcisi'nin sahip olması gerek yetenekler şunlardır:
#
# 1. Temel Araçlar: Python, R, SQL gibi temel dil ve araçlar hakkında bilgi sahibi olmak. Bu dil ve araçlar ile alakalı her şeyi bilmek şart değil. Aslında ihtiyacımız olan tek şey **Python** programlama dili desek yanlış olmaz.
#
# 1. Temel İstatistik: Mod, medyan, aritmetik ortalama(mean) ya da standart sapma(standard deviation) gibi temel istatitik yöntemleri hakkında bilgi sahibi olmak gerekiyor. Bu bilgiler sayesinde **Python** dilini kullanmamız çok daha kolay hale gelecek.
#
# 1. Data Munging(Ham Verilerin İşlenerek Daha Kullanışlı Hale Getirilmesi): Dağınık ve işlenmesi/temizlenmesi zor verilerle çalışabilmek de oldukça önemli bir meziyet. Örneğin string ve date verilerinin birbirleri ile tutarsız bir şekilde formatlandığı verilerle çalışmak oldukça zahmetlidir ancak tahmin edebileceğiniz üzere **Python** bu noktada da bize yardımcı olacak.
#
# 1. Data Visualization(Veri Görselleştirme): Adından da anlaşılacağı üzere verileri, daha anlaşılır ve faydalı olabilmesi için görselleştirme araçlarını kullanabilmek de veri bilimcinin yetileri arasında olmalı. Biz, **Python**'ın `Matplotlib` ve `Seaborn` gibi kütüphanelerini kullanarak veri görselleştirme çalışmaları yapacağız.
#
# 1. Machine Learning(Makine Öğrenmesi): Makine Öğrenmesi üzerine bilgi sahibi olmak. Makine Öğrenmesinin, üzerine inşa edildiği matematiğe derinlemesine hakim olmak ön koşul değildir. Bununla birlikte temel makine öğrenmesi tekniklerini ve bu tekniklerin **Python** ile nasıl uygulandığını bilmek yeterlidir.
#
# ### Kısacası, bir Veri Bilimcisi olabilmek için Python öğrenmek en önemli şart diyebiliriz.
#
# ***
#
# **İÇERİK**
# 1. [Introduction to Python](#1)
#     1. [Matplotlib](#2)
#     1. [Dictionaries](#3)
#     1. [Pandas](#4)
#     1. [Logic, control flow and filtering](#5)
#     1. [Loop data structures](#6)
# 1. [Python Data Science Toolbox](#7)
#     1. [User defined function](#8)
#     1. [Scope](#9)
#     1. [Nested function](#10)
#     1. [Default and flexible arguments](#11)
#     1. [Lambda function](#12)
#     1. [Anonymous function](#13)
#     1. [Iterators](#14)
#     1. [List comprehension](#15)
# 1. [Cleaning Data](#16)
#     1. [Diagnose data for cleaning](#17)
#     1. [Exploratory data analysis](#18)
#     1. [Visual exploratory data analysis](#19)
#     1. [Tidy data](#20)
#     1. [Pivoting data](#21)
#     1. [Concatenating data](#22)
#     1. [Data types](#23)
#     1. [Missing data and testing with assert](#24)
# 1. [Pandas Foundation](#25)
#     1. [Review of pandas](#26)
#     1. [Building data frames from scratch](#27)
#     1. [Visual exploratory data analysis](#28)
#     1. [Statistical explatory data analysis](#29)
#     1. [Indexing pandas time series](#30)
#     1. [Resampling pandas time series](#31)
# 1. [Manipulating Data Frames with Pandas](#32)
#     1. [Indexing data frames](#33)
#     1. [Slicing data frames](#34)
#     1. [Filtering data frames](#35)
#     1. [Transforming data frames](#36)
#     1. [Index objects and labeled data](#37)
#     1. [Hierarchical indexing](#38)
#     1. [Pivoting data frames](#39)
#     1. [Stacking and unstacking data frames](#40)
#     1. [Melting data frames](#41)
#     1. [Categoricals and groupby](#42)
#
# **KAYNAKLAR**
#
# 1. Data Visualization
#     1. Seaborn: https://www.kaggle.com/kanncaa1/seaborn-for-beginners
#     1. Bokeh 1: https://www.kaggle.com/kanncaa1/interactive-bokeh-tutorial-part-1
#     1. Rare Visualization: https://www.kaggle.com/kanncaa1/rare-visualization-tools
#     1. Plotly: https://www.kaggle.com/kanncaa1/plotly-tutorial-for-beginners
# 1. Machine Learning
#     1. https://www.kaggle.com/kanncaa1/machine-learning-tutorial-for-beginners/
# 1. Deep Learning
#     1. https://www.kaggle.com/kanncaa1/deep-learning-tutorial-for-beginners
# 1. Time Series Prediction
#     1. https://www.kaggle.com/kanncaa1/time-series-prediction-tutorial-with-eda
# 1. Statistic
#     1. https://www.kaggle.com/kanncaa1/basic-statistic-tutorial-for-beginners
# 1. Deep Learning with Pytorch
#     1. Artificial Neural Network: https://www.kaggle.com/kanncaa1/pytorch-tutorial-for-deep-learning-lovers
#     1. Convolutional Neural Network: https://www.kaggle.com/kanncaa1/pytorch-tutorial-for-deep-learning-lovers
#     1. Recurrent Neural Network: https://www.kaggle.com/kanncaa1/recurrent-neural-network-with-pytorch

# %%
# Eğer çalışmalarınızı Kaggle üzerinde gerçekleştiriyorsanız, her biri oldukça işlevsel birçok kütüphane,
# Python 3 ortamında kurulu olarak gelmektedir. Bu kütüphaneler kaggle/python docker image ile tanımlanır,
# bkz. https://github.com/kaggle/docker-python

# Eğer çalışmalarınızı lokal ortamda, yani direkt olarak bilgisayarınız üzerinde gerçekleştiriyorsanız,
# ihtiyaç duyduğunuz kütüphaneleri Python sanal ortamınıza kurmanız gerekmektedir.
# Aşağıda, `import` anahtar sözcüğü ile projeye dahil edilen bazı kütüphaneleri görebilirsiniz.

import numpy as np  # Linear algebra(lineer cebir) işlemleri yapabilmemizi sağlar
import pandas as pd  # Data processing(Veri işleme), CSV dosyası I/O işlemleri(ör. pd.read_csv)
import matplotlib.pyplot as plt # Data Visualization Tool
import seaborn as sns # Data Visualization Tool(veri görselleştirme aracı)

# Girdi olarak kullanacağımız dosyalar "../Data Science Tutorial/datasets" dizininde mevcuttur.
# Bu kod hücresini çalıştırdığımızda datasets dizini altındaki girdi dosyaları listelenecektir.
# Eğer lokalde çalışıyorsanız girdi dosyalarınızın bulunduğu dizini kullanmalısınız.
# Eğer kaggle ortamında çalışıyorsanız "../input" dizinini kullanmalısınız.

from subprocess import check_output
print(check_output(["ls", "../DataScienceTutorial/datasets"]).decode("utf-8"))

import os
for dirname, _, filenames in os.walk("/home/can/Documents/GitHub/DataScienceTutorial/datasets"):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
# Geçerli dizine yazdığınız tüm sonuçlar çıktı olarak kaydedilir.
# Out:
# combats.csv
# pokemon.csv
# tests.csv

# %% [markdown]
# **UYARI**
#
# * Yukarıdaki kod bloğunu çalıştırdığınızda elde ettiğiniz çıktı ne ise read_csv() metodu içerisine onu yazmanız gerekiyor.
# * Mesela, eğer yukarı bulunan kodu çalıştırdığınızda, resimdeki gibi bir output alıyorsanız, pd.read_csv() içerisine görseldeki ".csv" yolunu input olarak vermeniz gerekli (görselde olduğu gibi). Yukarıda kod bloğunu run edince ne çıkıyorsa onu yazmanız lazım mesela aşağıdaki gibi.
# <a href="https://ibb.co/Hg0QX2h"><img src="https://i.ibb.co/ZT3CNJ2/sil.png" alt="sil" border="0"></a>
# * read_csv içerisine yukarıda çıkan .csv dosyaları yazılmalı.

# %%
# Kaggle'da çalışanlar için örnek kod:

# data = pd.read_csv('/kaggle/input/pokemon.csv')
# data.head()

# %%
# CSV dosyası içerisindeki veriyi Pandas kütüphanesinin read_cvs() metodu ile data değişkenine import ediyoruz.
# Bu işlemi, "datayı import" etmek şeklinde adlandırabiliriz.

data = pd.read_csv("/home/can/Documents/GitHub/IntroductionToMachineLearning/DataScienceTutorial/datasets/pokemon.csv")

# %%
# Import ettiğimiz datanın ilk beş örneğini görelim.

data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
# Veri ile alakalı bazı bilgileri info() metodunu kullanarak inceliyebiliriz.

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
# Feature'lar arasındaki korelasyon(correlation) değerlerini inceleyelim.

# Correlation değeri 1'e yaklaştıkça pozitive correlation yani doğru orantı vardır diyebiliriz.
# Correlation değeri 0 ise, gözlemlenen iki feature arasında bir ilişki yok diyebiliriz.
# Correlation değeri -1'e yaklaştıkça negative correlation yani ters orantı vardır diyebiliriz.

# Örneğin, elimizde bir evin oda sayısı ile evin fiyatı bilgileri olsun.
# Bu bilgiler sahip olduğumuz iki feature'dur yani özniteliktir.
# Evin oda sayısı arttığında evin fiyatı da artıyorsa, bu iki feature, birbiri ile pozitif ilişkilidir.
# Yani bu iki öznitelik arasında pozitive correlation mevcuttur diyebiliriz.

# corr() metodu, korelasyon değerlerini dataframe formatında yazdırır.

data.corr()
# Out:
#                    #        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# #           1.000000  0.097712  0.102664  0.094691  0.089199  0.085596
# HP          0.097712  1.000000  0.422386  0.239622  0.362380  0.378718
# Attack      0.102664  0.422386  1.000000  0.438687  0.396362  0.263990
# Defense     0.094691  0.239622  0.438687  1.000000  0.223549  0.510747
# Sp. Atk     0.089199  0.362380  0.396362  0.223549  1.000000  0.506121
# Sp. Def     0.085596  0.378718  0.263990  0.510747  0.506121  1.000000
# Speed       0.012181  0.175952  0.381240  0.015227  0.473018  0.259133
# Generation  0.983428  0.058683  0.051451  0.042419  0.036437  0.028486
# Legendary   0.154336  0.273620  0.345408  0.246377  0.448907  0.363937
#
#                Speed  Generation  Legendary
# #           0.012181    0.983428   0.154336
# HP          0.175952    0.058683   0.273620
# Attack      0.381240    0.051451   0.345408
# Defense     0.015227    0.042419   0.246377
# ...

# %%
# Correlation Heatmap
# Seaborn kütüphanesinin bize sunduğu imkanlardan biridir.

# Feature'lar arasındaki korelasyon ilişkilerini görselleştirerek daha iyi anlamamızı sağlayan görselleştirme aracıdır.
# corr() metodunu kullanarak dataframe formatında yazdırdığımız korelasyon değerlerini heatmap() metodu ile
# görselleştirerek daha anlaşılır ve şık hale getiriyoruz.

# heatmap() metodu, parametre olarak;
    # data.corr() -> Dataframe formatında korelasyon verileri
    # annot -> Heatmap'in kareleri üzerinde yazan sayıların görünüp görünemeyeceğini belirlememizi sağlar
    # linewidths -> Kareler arasındaki çizginin kalınlığını belirler
    # fmt -> Precision(hassasiyet) değerini belirler(0'dan sonra yazdırılacak değer sayısı)
    # ax -> matplotlib.axes

# subplots() metoduna figsize=(18, 18) şeklinde parametre vererek görsel boyutunu ayarlıyoruz.

f, ax = plt.subplots(figsize=(18, 18))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt=".1f",ax=ax)
plt.show()

# %%
# İlk 10 pokemona ait verileri yazdırıyoruz.

data.head(10)
# Out:
#     #              Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0   1         Bulbasaur  Grass  Poison  45      49       49       65       65
# 1   2           Ivysaur  Grass  Poison  60      62       63       80       80
# 2   3          Venusaur  Grass  Poison  80      82       83      100      100
# 3   4     Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4   5        Charmander   Fire     NaN  39      52       43       60       50
# 5   6        Charmeleon   Fire     NaN  58      64       58       80       65
# 6   7         Charizard   Fire  Flying  78      84       78      109       85
# 7   8  Mega Charizard X   Fire  Dragon  78     130      111      130       85
# 8   9  Mega Charizard Y   Fire  Flying  78     104       78      159      115
# 9  10          Squirtle  Water     NaN  44      48       65       50       64
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# ...

# %%
# Verinin sahip olduğu feature'ları yazdırıyoruz.
# Her bir feature, sütun olarak karşımıza çıkar.

data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ***
# <a id="1"></a>
# # I. INTRODUCTION TO PYTHON

# %% [markdown]
# <a id="2"></a>
# ## MATPLOTLIB
# Matplotlib, verinin bir çizimini(plot) oluşturarak görselleştirmemizi sağlayan kütüphanedir. Oluşturması en basit ve en çok kullanılan diyagramlar ise **Line Plot, Scatter Plot ve Histogram**'dır. Peki hangi görselleştime seçeneğini ne zaman kullanırsak verimli bir sonuç elde ederiz?
# * Grafiğin x ekseninde "zaman" değişkeni mevcutsa *Line Plot* kullanmak mantıklıdır.
# * İki değişken/feature arasında korelasyon(correlation) mevcutsa *Scatter Plot* kullanmak mantıklıdır.
# * Sayısal verilerin dağılımını görmek istiyorsak *Histogram* kullanmak mantıklıdır.
# * Customization(Özelleştirme): Renkler, etiketler(labels), çizgi kalınlığı, başlık, saydamlık, ızgara(grid), şekil boyutu(figsize), eksen çizgileri ve çizgi stili(linestyle)

# %% [markdown]
# ### LINE PLOT OLUŞTURALIM

# %%
# Line Plot

# color = renk
# label = etiket
# linewidth = çizgi kalınlığı
# alpha = saydamlık
# grid = grid/ızgara
# linestyle = çizgi stili

plt.subplots(figsize=(15, 15))

data["Speed"].plot(kind = 'line', color = 'g', label = 'Speed', linewidth=1, alpha = 0.5, grid = True, linestyle = '-')
data["Defense"].plot(color = 'r',label = 'Defense',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')

plt.legend(loc='upper right')     # legend = eksen etiketlerini ve konumunu belirle
plt.xlabel('x axis')             
plt.ylabel('y axis')
plt.title('Line Plot')
plt.show()

# %% [markdown]
# ### SCATTER PLOT OLUŞTURALIM

# %%
# Scatter Plot

# İki feature arasındaki positive correlation ve negative correlation değişimlerini inceleyeceğiz
# Feature'lar;
    # x = Attack
    # y = Defense

data.plot(kind='scatter', x='Attack', y='Defense', alpha = 0.5, color = 'red', figsize=(15,7))
plt.xlabel('Attack')
plt.ylabel('Defence')
plt.title('Attack Defense Scatter Plot')
plt.show()

# %%
# Scatter Plot oluştururken kullandığımız Attack ve Defense feature'ları data'mızın sütunlarıdır.
# Sütunları yazdıralım

data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# Bununla birlikte farklı bir yöntemle de Scatter Plot oluşturabiliriz:

plt.subplots(figsize=(15,7))

plt.scatter(data["Attack"], data["Defense"], color="red", alpha=0.5)

plt.xlabel('Attack')
plt.ylabel('Defence')
plt.title('Attack Defense Scatter Plot')
plt.show()

# %% [markdown]
# ### HISTOGRAM OLUŞTURALIM

# %%
# Histogram

# Data'nın Speed feature'unu, histogram plot ile görselleştiriyoruz.
# bins = Grafik üzerindeki "bar" sayısı
# x-ekseninde pokemonların hız değerleri bulunmakla beraber y-ekseninde ise belirtilen hıza sahip pokemon sayısı
# ifade edilmektedir -> Frequency

data["Speed"].plot(kind = 'hist', bins = 50, figsize = (12,12), color="g")

plt.xlabel("Speed of Pokemon")
plt.ylabel("How Many Pokemons")
plt.show()

# %%
# clf() = Bu metot çizdiğimiz plot'u clear eder yani ortadan kaldırır.

data["Speed"].plot(kind = 'hist',bins = 50)
plt.clf()

# Bu hücreyi çalıştırdığımızda histogramın clear edildiğini görebiliriz.

# %% [markdown]
# ***
# <a id="3"></a>
# ### DICTIONARY(SÖZLÜK)
# Neden dictionary veri yapısına ihtiyaç duyarız?
# * Çünkü dictionary, tıpkı küçük bir dataframe gibi içerisinde 'key' ve 'values' değerlerini bulundurur.
# * Dictionary, list veri yapısından daha hızlı çalışır.
# <br>
# 'key' ve 'value' değerleri nedir? Örnek:
# * dictionary = {'Spain' : 'Madrid'}
# * Key >>> Spain
# * Values >>> Madrid
# <br>
#
# **İşte bu kadar basit**
#
# Şimdi de, keys(), values(), güncelleme(update), ekleme(add), kontrol etme(chech), key silme(remove key), tüm girdileri silme(remove all entries) ve dictionary silme(remove dictinary) gibi metot ve özellikler ile alakalı uygulamalar yapalım.

# %%
# Bir dictionary yaratıp key ve values değerlerini inceleyim

dictInstance = {
    'Spain' : 'Madrid',
    'USA' : 'Vegas'
}

print(dictInstance.keys())
print(dictInstance.values())

# Görüldüğü üzere dictInstance adlı dictionary yapısının;

    # Key değerleri >> Spain ve USA
    # Values değerleri >> Madrid ve Vegas
# Out:
# dict_keys(['Spain', 'USA'])
# dict_values(['Madrid', 'Vegas'])

# %%
# Dictionary key'leri; tıpkı string, boolen, float, integer ya da tuple gibi immutable nesnelerdir.
# List veri yapısı mutable'dır. Bu nedenle key değeri olarak bir liste tercih edilemez.
# Key değerleri unique yani eşşizdir.

print(dictInstance)                    # dictInstance dictionary'sini yazdır ve ilk halini incele.

dictInstance['Spain'] = "Barcelona"    # Halihazırda var olan key'in values değişkenini güncelledik.
print(dictInstance)

dictInstance['France'] = "Paris"       # Yeni bir key-values ikilisini dictInstance yapımıza ekledik.
print(dictInstance)

del dictInstance['Spain']              # Spain key'ini, values değişkeni ile birlikte sildik.
print(dictInstance)

print('France' in dictInstance)        # France key'inin dictInstance yapısı içerisinde olup olmadığını kontrol et.

dictInstance.clear()                   # dictInstance içerisindeki tüm girdileri sil.
print(dictInstance)
# Out:
# {'Spain': 'Madrid', 'USA': 'Vegas'}
# {'Spain': 'Barcelona', 'USA': 'Vegas'}
# {'Spain': 'Barcelona', 'USA': 'Vegas', 'France': 'Paris'}
# {'USA': 'Vegas', 'France': 'Paris'}
# True
# {}

# %%
# Boş bir dictionary yapısının bellekte yer kaplaması mantıklı değil.
# Bu nedenle clear() metodu ile içini boşalttığımız dictInstance'ı tamamen silebiliriz.
# del dictInstance ifadesi dictionary yapısını silmemizi sağlar.
# Silinen bir dictionary'i yazdırmak hata vereceği için print() satırını yorum satırı yaptık.

del dictInstance
# print(dictInstance)

# %% [markdown]
# <a id="4"></a>
# ***
# ### PANDAS
#
# Pandas hakkında neler biliyoruz?
# Pandas iki çeşit veri tipinden oluşur. Bunlar;
# 1. Series
# 1. DataFrame
#
# Aslında bir üçüncü tip de mevcuttur ancak hiç kullanmayacağımız için burada üzerinde durmuyoruz.
#
# * CSV: comma - separated values - virgül ile ayırılmış değerler

# %%
data = pd.read_csv('datasets/pokemon.csv') # Verilerimizi(pokemon.csv) import ediyoruz

# %%
# Series ve DataFrame yapılarını inceleyelim

series = data['Defense']        # data['Defense'] = Series
print(type(series))

data_frame = data[['Defense']]  # data[['Defense']] = DataFrame
print(type(data_frame))

print("----------------------------------------")
print(data["Defense"])          # Series -> Vektörel yapıya sahip
print("----------------------------------------")
print(data[["Defense"]])        # DataFrame -> Tablo yapısına sahip
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# ----------------------------------------
# 0       49
# 1       63
# 2       83
# 3      123
# 4       43
#       ...
# 795    150
# 796    110
# 797     60
# 798     60
# 799    120
# Name: Defense, Length: 800, dtype: int64
# ----------------------------------------
#      Defense
# 0         49
# 1         63
# 2         83
# 3        123
# 4         43
# ..       ...
# 795      150
# 796      110
# 797       60
# 798       60
# 799      120
#
# [800 rows x 1 columns]

# %% [markdown]
# ***
# <a id="5"></a>
# Pandas ile devam etmeden önce;
#
# - **logic(mantık), control flow(akış kontrolü)** ve **filtering(filtreleme)**
#
# kavramlarına hakim olmamız gerekiyor.
#
# * Comparison operator(Karşılaştırma Operatörleri):  ==, <, >, <=
# * Boolean operators: and, or ,not
# * Filtering Pandas

# %%
# Comparison operator
print(3 > 2)
print(3!=2)

# Boolean operators
print(True and False)
print(True or False)
# Out:
# True
# True
# False
# True

# %% [markdown]
# ### 1 - Pandas ile DataFrame Filtreleme

# %%
# Defense değeri 200'den büyük olan pokemonları filtreliyoruz
x = data['Defense'] > 200
data[x]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 230  231       Shuckle    Bug    Rock  20      10      230       10      230
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 230      5           2      False
# 333     50           3      False

# %% [markdown]
# ### 2 - Numpy'ın *logical_and()* Metodu ile DataFrame Filtreleme

# %%
# Hem Defence değeri 200'den büyük olan hem de Attack değeri 100'den büyük olan pokemonları filtreliyoruz.

data[np.logical_and(data['Defense'] > 200, data['Attack'] > 100)]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 333     50           3      False

# %%
# Bir önceki kod hücresiyle aynı işi yapıyoruz. 
# Ancak burada logical_and() metodu yerine "&" operatörünü kullanıyoruz.

data[(data['Defense'] > 200) & (data['Attack'] > 100)]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 333     50           3      False

# %% [markdown]
# ***
# <a id="6"></a>
# ### WHILE AND FOR LOOPS - WHILE VE FOR DÖNGÜLERİ
# * `while` ve `for` döngülerini en basit şekilde öğreneceğiz.

# %%
# (i != 5) şartı True olduğu sürece while döngüsü içerisinde kal.

i = 0
while i != 5:
    print('i is: ', i)
    i +=1
print(i,' is equal to 5')
# Out:
# i is:  0
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# 5  is equal to 5

# %%
print("-------For List-------")

# for döngüsü örneği

lis = [1,2,3,4,5]
for i in lis:
    print(f'i is: {i}')
print('')

print("-------For Enumerate-------")

# enumerate -> liste yapısı içerisindeki değerleri ve o değerlerin listedeki indekslerini yazdırmamızı sağlar
# index : value = 0:1, 1:2, 2:3, 3:4, 4:5

for index, value in enumerate(lis):
    print(index," : ",value)
print('')   

print("-------For Dictionary-------")

# Dictionary yapısında döngüleri inceleyelim
# Dictionary'nin key ve values değerlerine erişebilmek için for döngüsü oluşturabiliriz.
# Bunu yapabilmek için dictionary veri yapısına ait olan items() metodunu kullanabiliriz.

dictionary = {
    'Spain':'Madrid',
    'France':'Paris'
}

for key, value in dictionary.items():
    print(key," : ",value)
print('')

print("-------For Pandas-------")

# Pandas verilerine erişim sağlamak için for döngüsü kullanabiliriz.
# Attack feature'unun ilk indeksindeki değeri -> [0:3] 
# iterrows() metodu ile, belirtilen indeksi ve o indeksteki değeri alıp index ve value değişkenlerine atıyoruz.
# Ardından for döngüsü ile yazdırıyoruz
for index, value in data[['Attack']][0:3].iterrows():
    print(index," : ",value)
# Out:
# -------For List-------
# i is: 1
# i is: 2
# i is: 3
# i is: 4
# i is: 5
#
# -------For Enumerate-------
# 0  :  1
# 1  :  2
# 2  :  3
# 3  :  4
# 4  :  5
#
# -------For Dictionary-------
# Spain  :  Madrid
# France  :  Paris
#
# -------For Pandas-------
# 0  :  Attack    49
# Name: 0, dtype: int64
# 1  :  Attack    62
# Name: 1, dtype: int64
# 2  :  Attack    82
# Name: 2, dtype: int64

# %% [markdown]
# **Bu bölümde şunları öğrendik:**
# * csv dosyalarını import etmek
# * plotting line, scatter and histogram
# * temel dictionary özellikleri
# * bir veri bilimcisinin her zaman kullandığı temel bir bilgi olan filtering gibi Pandas özellikleri
# * while ve for döngüsü

# %% [markdown]
# ***
# <a id="7"></a>
# # 2. PYTHON DATA SCIENCE TOOLBOX

# %% [markdown]
# <a id="8"></a>
# ### USER DEFINED FUNCTION - KULLANICI TANIMLI FONKSİYONLAR
# Peki, fonksiyonlar ile ilgili bilmemiz gereken kavramlar nelerdir?
# * docstrings: ait olduğu fonksiyonun işlevini özetleyen dökümanlardır. Örneğin:
#
# def f():
#     <br>"""This is docstring for documentation of function f"""
#
#
# * Tuple: birbiri ardına sıralanmış Python objelerini tutan veri yapısı.
#     1. Tuple içerisindeki değerler değiştirilemez çünkü tuple immutable'dır.
#     2. Tuple içerisindeki sıralı objeler parantez içerisinde belirtilir -> tupleInstance = (a,b,c)
#     3. Tuple içerisinde depolanan verileri birden fazla değişkene aktarabiliriz ve bu işleme `unpacking` denir

# %%
# Öğrendiklerimizi uygulayalım

def tupleInstance():
    """ return defined t tuple"""  # docstring
    t = (1,2,3)
    return t

a,b,c = tupleInstance()     # unpacking
print(a,b,c)
# Out:
# 1 2 3

# %% [markdown]
# ***
# <a id="9"></a>
# ### SCOPE - KAPSAM / FALİYET ALANI
# Peki, scope hakkında bilmemiz gereken kavramlar nelerdir?
# * local: Bir fonksiyon içerisinde tanımlanan değişkenlerin türü
# * enclosed: Eğer yerelde tanımlı değilse kapsayan fonksiyon içinde yer alan değer kullanılır
# * global: main body(ana gövde) içerisinde tanımlanan değişkenlerin türü
# * built in scope: Bizim tanımlamadığımız, Python ile birlikte gelen fonksiyon ya da değişkenlerdir. Örn: print(), len()
# <br><br>Lets make some basic examples

# %%
# print() fonksiyonu sonucunda hangi değerlerin yazdırılacağını tahmin etmeye çalışın

x = 2
def f():
    x = 3
    return x

print(x)      # x = 2 global scope
print(f())    # x = 3 local scope
# Out:
# 2
# 3

# %%
# Peki kullanmak istediğimiz değişken local scope içerisinde tanımlı değilse ne olur?

x = 5              # global değişken

def f():
    y = 2*x        # fonksiyonda, yani local scope içerisinde tanımlı bir x değişkeni yok
    return y

print(f())         # global scope içerisinde tanımlanan x değişkeni kullanılır.

# Yukarıdaki script'i inceleyelim;
# f() fonksiyonu içerisinde x değişkeni aranır, 
# Eğer yoksa global scope içerisinde bir x değişkeni olup olmadığına bakılır.
# Eğer global scope içerisinde de bir x değişkeni yoksa built in scope içerisinde bir x değişkeni aranır.
# Out:
# 10

# %%
# built in scope içerisindeki değişken ya da fonksiyonları nasıl öğrenebiliriz?

import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
# ...

# %% [markdown]
# ***
# <a id="10"></a>
# ### NESTED FUNCTION - İÇ İÇE FONKSİYON
# * LEGB kuralına göre değişken arama sırası:
#     * Local scope
#     * Enclosed function
#     * Global scope
#     * Built in scope

# %%
# İç içe fonksiyon örneği

def square():
    """ return square of value """
    
    def add():
        """ add two local variable """
        x = 2
        y = 3
        z = x + y
        return z
    
    return add()**2

print(square())
# Out:
# 25

# %% [markdown]
# ***
# <a id="11"></a>
# ### DEFAULT AND FLEXIBLE ARGUMENTS
# 1. *Default argument örneği:*
#
#     def f(a, b=1):
#         """b = 1 is default argument"""
#
# 1. *Flexible argument örneği:*
#
#   <br>def f(*args):
#        """ *args kullanarak bir ya da daha fazla argüman alabiliriz."""
#
#     def f(**kwargs)
#        """kwargs bir dictionary veri yapısıdır."""
#
# <br> Birkaç pratik yapalım.

# %%
# default arguments

def f(a, b = 1, c = 2):
    y = a + b + c
    return y

print(f(5))

# peki default arguments olarak belirlenen değişkenlere farklı bir değer atamak istersem?
print(f(5,4,3))

# atarım :)
# Out:
# 8
# 12

# %%
# Flexible arguments: *args
# Fonksiyona değişken sayıda parametre yollamak istersek *args kullanırız.

def f(*args):
    for i in args:
        print(i)
        
f(1)
print("")
f(1,2,3,4)

# Flexible arguments **kwargs dictionary yapısına değişken sayıda parametre göndermek için kullanılır.
def f(**kwargs):
    """ print key and value of dictionary"""
    
    # Eğer aşağıdaki kısmı anlamadıysanız for döngüsü kullanarak dictionary işlemleri yaptığımız bölümü tekrar edin
    for key, value in kwargs.items():
        print(f"Key değeri: {key} , Value değeri: {value}")
        
f(country = 'spain', capital = 'madrid', population = 123456)
# Out:
# 1
#
# 1
# 2
# 3
# 4
# Key değeri: country , Value değeri: spain
# Key değeri: capital , Value değeri: madrid
# Key değeri: population , Value değeri: 123456

# %% [markdown]
# ***
# <a id="12"></a>
# ### LAMBDA FUNCTION
# **Hızlı ve pratik bir şekilde fonksiyon yazmamızı sağlayan yöntem**

# %%
# normal yöntem
def square(x):
    return x**2
print(square(5))

# lambda fonksiyonu
square = lambda x: x**2     # x, lamda fonksiyonuna gönderilen parametredir
print(square(4))

total = lambda x,y,z: x+y+z   # x, y ve z, lamda fonksiyonuna gönderilen parametrelerdir
print(total(1,2,3))
# Out:
# 25
# 16
# 6

# %% [markdown]
# ***
# <a id="13"></a>
# ### ANONYMOUS FUNCTİON
# Bu fonksiyonun lamda fonksiyonunda tek farkı birden fazla argüman alabilmesidir.
# * **map(func,seq)** : liste içerisinde bulunan tüm objeleri, fonksiyona parametere olarak gönderir

# %%
number_list = [1,2,3]

y = map(lambda x:x**2, number_list)

print(list(y))
# Out:
# [1, 4, 9]

# %% [markdown]
# ***
# <a id="14"></a>
# ### ITERATORS - YİNELEYİCİLER
# * *iterators*, Python’a iterasyon özelliği kazandıran bir nesnedir. Verileri döndüren bu nesne, her seferinde bir öğe döndürür. Iterators, Pyhton programlama dilinde döngüler, liste, tuple ve generators gibi noktalarda karşımıza çıkar.
# * Python iterators nesnesi, `__iter__()` ve `__next__()` şeklinde iki özel metot içerir. Bu metotlardan bir değer alabilirsek iterator özelliğindeki bir nesne içinde olduğumuzu anlarız. Örneğin Python’da list, tuple, string ve dictionary bu özelliğe sahiptir.
# - `__iter__()` -> Bir iteratörün başlatılmasında çağrılır. Bir sonraki adıma geçebilen veya `__next__` yöntemine sahip bir nesne döndürmelidir. Yani geriye `iterable` bir nesne döndürür.
# - `__next()` -> **Iterator**, iterable bir obje için bir sonraki değeri döndürür.

# %%
# iteration örneği

name = "ronaldo"
itr = iter(name)    # it değişkeni, name stringini alıp iterable olan bir nesneyi alıyor
print(next(itr))    # biri sonraki iteration'u yazdır
print(*itr)         # iterable nesnenin geri kalanını yazdır.

name = "karabük"
itr2 = iter(name)

for i in itr2:
    print(i)
# Out:
# r
# o n a l d o
# k
# a
# r
# a
# b
# ü
# k

# %% [markdown]
# **zip()**: zip lists, iki listeyi tuple formatında birleştirir.

# %%
# zip örneği

list1 = [1,2,3,4]
list2 = [5,6,7,8]

z = zip(list1,list2)      # zip objesi yaratıldı ve z değişkenine atandı.
print(z)

z_list = list(z)
print(z_list)
# Out:
# ...
# [(1, 5), (2, 6), (3, 7), (4, 8)]

# %%
un_zip = zip(*z_list)
un_list1, un_list2 = un_zip # unzip işlemi geriye tuple döner

print(un_list1)
print(un_list2)

print(type(un_list1))
print(type(un_list2))

print("")

unzList1 = list(un_list1)
unzList2 = list(un_list2)

print(unzList1)
print(unzList2)

print(type(unzList1))
print(type(unzList2))
# Out:
# (1, 2, 3, 4)
# (5, 6, 7, 8)
# <class 'tuple'>
# <class 'tuple'>
#
# [1, 2, 3, 4]
# [5, 6, 7, 8]
# <class 'list'>
# <class 'list'>

# %% [markdown]
# ***
# <a id="15"></a>
# # LIST COMPREHENSİON
# **Bu tutoria içerisindeki en önemli konulardan birine giriş yapıyoruz.**
#
# * List Comprehension yöntemini, sıklıkla `Data Analysis- Veri Analizi` yapmak için kullanırız.
# * List Comprehension yöntemi, *for* döngüsü ile iki üç satırda tanımlayabileceğimiz listeleri tek satırda tanımlama imkanı sunar.
# * Örnek olarak, num1 = [1, 2, 3] listesinin içerisindeki değerleri bir arttırarak num2 = [2, 3, 4] haline getirmek istiyoruz. Bu işlemi pek ala bir for döngüsü ile yapabiliriz ancak hem zaman hem de performans verimliliği sağlamak adına *List Comprehension* tekniğini uygulayacağız.

# %% [markdown]
# ## List Comprehension Örneği

# %%
# Klasik yöntem
num1For = [1,2,3]
num2For = [0,0,0]

for index, value in enumerate(num1For):
    num2For[index] = value + 1

print(num2For)
# Out:
# [2, 3, 4]

# %%
# list comprehension örneği

num1 = [1,2,3]
num2 = [i + 1 for i in num1]

print(num2)
# Out:
# [2, 3, 4]

# %% [markdown]
# * `[i + 1 for i in num1]` -> list of comprehension
#
#     * i +1: list comprehension sentaksı
#     * for i in num1: for söngüsü sentaksı
#     * i: iteratör
#     * num1: itere edilebilen nesne

# %%
# List Comprehension yaparken döngüler ve koşullar kullanmak

num1 = [5,10,15]
num2 = [i**2 
        if i == 10 
        else 
        i-5 
        if i < 7 
        else
        i+5 
        for i in num1]

print(num2)
# Out:
# [0, 100, 20]

# %% [markdown]
# **Yukarıdaki işlemleri şu şekilde açıklayabiliriz:**
# * Öncelikle *for i in num1* döngüsünü dikkate alarak başlayacağız;
#     * Eğer i == 10 True ise;
#          * `for in num1` döngüsünü `i**2` için çalıştırırız
#     * Eğer i < 7 True ise;
#          * `for in num1` döngüsünü `i-5` için çalıştırırız
#     * Eğer i == 10 False ve i < 7 False ise;
#          * `for in num1` döngüsünü `i+5` için çalıştırırız

# %%
# Şimdi de pokemon.csv dosyamız üzerinde List Comprehension yapalım.
# Pokemonların "Speed" feature'unu göz önünde bulundurarak "yavaş" ya da "hızlı" olup olmadılarına bakalım.
# Karşılaştırma değerimizi ortalama hız olacak şekilde belirliyoruz.

threshold = sum(data["Speed"]) / len(data["Speed"])    # Ortalama Hız hesabı
print(f"Threshold Value = {threshold}")

data["SpeedLevel"] = ["High" 
                       if i > threshold 
                       else 
                       "Low" 
                       for i in data["Speed"]]

data.loc[:10,["SpeedLevel","Speed"]]             # loc metodunu ilerleyen zamanlarda öğreneceğiz
# Out:
# Threshold Value = 68.2775
#    SpeedLevel  Speed
# 0         Low     45
# 1         Low     60
# 2        High     80
# 3        High     80
# 4         Low     65
# 5        High     80
# 6        High    100
# 7        High    100
# 8        High    100
# 9         Low     43
# 10        Low     58

# %% [markdown]
# **Bu bölümde şunları öğrendik:**
# * User Defined Functions
# * Scope
# * Nested Functions
# * Default and Flexible Arguments
# * Lambda Functions
# * Anonymous Functions
# * Iterators
# * List Comprehension

# %% [markdown]
# ***
# <a id="16"></a>
# # 3. CLEANING DATA - VERİ TEMİZLEME

# %% [markdown]
# <a id="17"></a>
# ### DIAGNOSE DATA FOR CLEANING
# Elimizdeki veri ile çalışmalar yapmadan önce diagnosing(teşhis etme) ve cleaning(temizleme) işlemlerini gerçekleştirmemiz gerekiyor
# * **Unclean Data:**
#     * Bu datalar'ın column(sütun) isimlerinde tutarsızlıklar mevcuttur. Örneğin, büyük-küçük harf karmaşası ya da kelimeler arasındaki boşluklar vs. Bu problemin üstesinden gelebilmek için sütun isimlerinin tamamını büyük ya da tamamını küçük olacak şekilde düzeltebilir ve kelimeler arasında boşluk olmayacak şekilde isimlendirmeler yapabiliriz.
#     * Missing data - Kayıp veri (NaN, --)
#     * Dil ve karakter farklılığı
#
# `Veri üzerinde teşhis yapabilmek için head(), tail(), columns, shape ve info() metotlarını kullanacağız.`

# %%
# Datamızı import edelim.
data = pd.read_csv('datasets/pokemon.csv')

# %%
# Elimizdeki datanın ilk 5 satırını inceleyelim.
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
# tail() metodunu kullanarak datamızın son 5 satırını da inceleyelim.
data.tail()
# Out:
#        #            Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  796         Diancie     Rock  Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock  Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic  Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic   Dark  80     160       60      170
# 799  800       Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
# columns metodu, data framede bulunan feature'ları yani sütunları yazdırır.
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# shape metodu data framedeki satır ve sütun sayılarını verir.
data.shape
# Out:
# (800, 12)

# %%
# info() metodu, veri ile alakalı çeşitli bilgiler edinmemizi sağlar.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %% [markdown]
# ***
# <a id="18"></a>
# ### EXPLORATORY DATA ANALYSIS - KEŞİFSEL VERİ ANALİZİ
# * `value_counts() metodu`: Verinin keşfi sırasında kullanılan metottur. Sütundaki(features), NaN olmayan her bir unique değerin kaç kez kullanıldığını gösteren bir seri döndürür. Bu seri default olarak azalan sırada(descending) gösterilir. Aslında features değerlerinin frequency bilgisine ulaşıyoruz. Bu bilgi üzerinden yorumlamalar yaparak hatalı veri bulma şansımızı arttırabiliriz.
#
#
# * `Outlier(Aykırı Değer)`: Halihazırda yapılmış olan gözlemlerden kayda değer derecede uzak olan, gözleme aykırı veya uç değerlere *outliers* denir. Aykırı gözlemler, veri setinin geri kalanından farklı davranır ve bu nedenle dikkat çeker. Veri içerisindeki değerlerin dağımı ile kıyaslandığında, gözle görülür derecede yüksek ya da düşük değerleri outlier olarak değerlendirebiliriz.
#
#
# * Diyelim ki Q3 = %75 ve Q1 = %25. Buna göre;
#     * **Q3 + 1.5(Q3-Q1) < OUTLIER < Q1 - 1.5(Q3-Q1)**
#         * **Q3 - Q1 = IQR(Interquartile Range - Çeyrekler Açıklığı)**
#     * Outlier değerleri Q1 - 1.5(Q3 - Q1) değerinde küçük ve Q3 + 1.5( Q3 - Q1) değerinden büyüktür.
#
#
# * Ayrıca `describe()` metodunu kullanacağız. describe() metodu aşağıdakileri içerir:
#     * count: veri içerisindeki girdi sayısı
#     * mean: girdilerin ortalaması
#     * std: standart deviation(standart sapma)
#     * min: minimum girdi
#     * 25%: ilk yüzdelik dilim(firs quantile)
#     * 50%: ortanca değer ya da ikinci yüzdelik dilim(second quantile or median)
#     * 75%: üçüncü yüzdelik dilim(third quantile)
#     * max: maksimum girdi
#
#
# * `Quartile(Çeyrek)` Nedir?
#     * 1, 4, 5, 6, 8, 9, 11, 12, 13, 14, 15, 16, 17
#     * Median(medyan), sayı dizisi içerisindeki ortanca değerdir. Bu senaryoda median = 11
#     * `Lower Quartile(İlk Çeyrek/Birinci Kartil)`: Serinin başındaki ile serinin ortasındaki sayı arasında kalan sayıların medyanına denir. Bu senaryoda 1-11 arasındaki değerlerin medyanı olan 6 lower quartile'dir.
#     * `Upper Quartile(Üst Çeyrek/Üst Kartil)`: Serinin ortasındaki sayı ile serinin sonundaki sayı arasında kalan sayıların medyanına denir. Bu senaryoda 11-17 arasındaki değerlerin medyanı olan 14 upper quartile'dir.
#
#
# * `Quantile ve Quartile İlişkisi`
#     * **Lower Quartile = Q1 = %25 Quantile**
#     * **Upper Quartile = Q3 = %75 Quantile**

# %% [markdown]
# <img src="outliersBoxplot.png"/>

# %%
# pokemon.csv içerisindeki pokemonların tiplerinin tekrar etme sayılarını inceleyelim.
# value_counts() metosu içerisindeki "dropna=False" ifadesi, eğer tipler içerisinde NaN değer varsa, o değerin de hesaba katılacağını ifade eder.

print(data['Type 1'].value_counts(dropna =False))
# Aşağıda görebileceğiniz üzere veri setimizde 112 Water tipi ve 70 Grass tipi pokemon mevcuttur.
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
# describe() metodu, sayısal verilere sahip olan sütunların max, min, std… gibi istatiksel değerlerini döndürür.
# null değerleri görmezden gelir.
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %% [markdown]
# Bu noktada neden hem mean hem de medyan değerlerini hesapladığımız hakkında kısaca bir bilgi verelim. Diyelim ki bir şirkette çalışansınız ve patronunuz size zam yapmayı düşünüyor. Zam yapmadan önce şirket çalışanlarının maaşlarının ortalamasını(mean) görmek ve buna göre zam yapmak istiyor olsun. Şirkette 10 adet çalışan olduğunu ve bu çalışanların şu maaşları aldığını farz edelim:
#
#     * 500, 500, 500, 500, 500, 500, 500, 500, 500, 30.000
#
# Bu dağılım için Mean = 3450'dir. Patron bu sayıyı gördüğünde zam yapması gerektiğini düşünmeyebilir ya da az zam yapabilir. Ancak Median değeri incelendiğinde 500 değeri görülür ve çalışanların yarısının 500 ve altı miktarda maaş aldığı anlaşılarak gereken zammı yapabilir.
#
# Kısacası Mean değerinin sonucunda yanlış bir bilgiye ulaşmamak için Median bilgisini de incelememiz gerekir

# %% [markdown]
# ***
# <a id="19"></a>
# ### VISUAL EXPLORATORY DATA ANALYSIS - GÖRSEL KULLANARAK KEŞİFSEL VERİ ANALİZİ
# * **Boxplot(Kutu Grafiği)**: Veri çeyreklerini(quartile), yüzdelikleri(quantile), ortalamaları(mean), outliers değerleri ve min/max deperleri görüntüleyerek sayısal verilerin ve değişkenliğin görsel olarak dağılımını göstermek için kullanılır. Veri analizinde sıklıkla kullanılan bir grafik türüdür.

# %%
# Örneğin: Pokemonların Attacks feature'unu, Legendary olup olmamasına göre karşılaştıralım.
# Siyah çizgilerin altında ve üstünde olan daire ile işaretli olan kısımlar -> Outlier

data.boxplot(column='Attack', by = 'Legendary')
plt.show()

# %% [markdown]
# ***
# <a id="20"></a>
# ### TIDY DATA - DÜZENLİ VERİ
#
# * Düzenli Veride;
#     * Her sütun bir değişkeni temsil eder.
#     * Her satır bir gözlemi temsil eder.
#     * Her bir gözlem birimi bir tablo oluşturur.
#
# Verileri, melt() metodu ile düzenli hali getirmeye çalışacağız. Bu metot verilerin değerlerinin sabit kalması koşuluyla veriyi farklı bir yapıya büründürür. Kısacası üzerinde çalıştığımız data frame'den belli başlı yeni feature'lar çıkararak yeni bir data frame oluşturuyoruz.

# %%
# melt() metodunu inceleyebilmek adına, dataNew adından bir değişken yaratıyoruz.
# Ardından pokemon veri setinin ilk beş satırını bu değişkene atıyoruz.

dataNew = data.head()

# %%
# Oluşturduğumuz bu data frame'i inceleyelim.
dataNew
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
# Melt işlemine başlayalım

# melt() metodunun parametreleri;
# frame = Melt edeceğimiz data frame.
# id_vars = Melt ederek yeniden formatlayacağımız data frame içerisinde değişmeden kalmasını istediğimiz feature.
# value_vars = Melt etmek ve yeni bir isimle data frame'e eklemek istediğimi feature/feature'lar.

melted = pd.melt(frame=dataNew, id_vars = 'Name', value_vars = ['Attack','Defense'])

# %%
# Oluşan yeni data frame'i inceleyelim
melted
# Out:
#             Name variable  value
# 0      Bulbasaur   Attack     49
# 1        Ivysaur   Attack     62
# 2       Venusaur   Attack     82
# 3  Mega Venusaur   Attack    100
# 4     Charmander   Attack     52
# 5      Bulbasaur  Defense     49
# 6        Ivysaur  Defense     63
# 7       Venusaur  Defense     83
# 8  Mega Venusaur  Defense    123
# 9     Charmander  Defense     43

# %% [markdown]
# Melt işlemini yapmamızın temel sebebi, üzerinde çalıştığımız verileri Seaborn kütüphanesini kullanarak görselleştirirken melt() metodu ile formatladığımız verilerin daha belirgin bir şekilde görsel hale gelebilmesidir.

# %% [markdown]
# ***
# <a id="21"></a>
# ### PIVOTING DATA
# * *melt()* metodu ile yaptığımız işlemleri tersine döndürür.

# %%
# Index -> Name
# Sütunları variable yapmak istiyoruz

melted.pivot(index = 'Name', columns = 'variable', values='value')
# Out:
# variable       Attack  Defense
# Name
# Bulbasaur          49       49
# Charmander         52       43
# Ivysaur            62       63
# Mega Venusaur     100      123
# Venusaur           82       83

# %% [markdown]
# ***
# <a id="22"></a>
# ### CONCATENATING DATA - VERİLERİ BİRLEŞTİRME
# * İki DataFrame'i birleştirebiliriz.

# %%
# Öncelikle iki adet data frame oluşturalım

data1 = data.head() # Pokemon datasının ilk beş sample'ı  
data2 = data.tail() # Pokemon datasının son beş sample'ı  

# axis = 0 -> dataframe'lerin satırlarını birleştiriyoruz. Yani vertical bir yerleşim söz konusu.
# ignore_index = True -> Halihazırdaki index değerlerini görmezden gel ve yeni index değerleri ata.
concDataRow = pd.concat([data1, data2], axis = 0, ignore_index = True)

# %%
# Oluşturduğumuz yeni data frame'i inceleyelim
concDataRow
# Out:
#      #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1       Bulbasaur    Grass  Poison  45      49       49       65
# 1    2         Ivysaur    Grass  Poison  60      62       63       80
# 2    3        Venusaur    Grass  Poison  80      82       83      100
# 3    4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4    5      Charmander     Fire     NaN  39      52       43       60
# 5  796         Diancie     Rock   Fairy  50     100      150      100
# 6  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 7  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 8  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 9  800       Volcanion     Fire   Water  80     110      120      130
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# ...

# %%
# axis = 1 -> dataframe'lerin sütunlarını birleştiriyoruz. Yani horizontal bir yerleşim söz konusu.

data1 = data['Attack'].head()
data2 = data['Defense'].head()

conc_data_col = pd.concat([data1,data2], axis = 1) 
conc_data_col
# Out:
#    Attack  Defense
# 0      49       49
# 1      62       63
# 2      82       83
# 3     100      123
# 4      52       43

# %% [markdown]
# ***
# <a id="23"></a>
# ### DATA TYPES - VERİ TİPLERİ
# * 5 temel veri tipi mevcuttur, bunlar:
#     * Object(string)
#     * Boolean
#     * Integer
#     * Float
#     * Category
#
# * Veri tipleri arasında dönüşüm yapmak mümkündür. Örneğin str'den categorical'a ve float'tan int'e
# * Category veri tipi neden önemlidir?
#     * DataFrame'lerin bellekte kapladığı alanı azaltır.
#     * Veri analizinde kullanılabilir, özellikle scikit-learn kütüphanesini kullanırken çokça karşılaşacağız.

# %%
# Data frame içerisindeki veri tiplerini inceleyelim
data.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
# object(str)'den category veri tipine ve int'ten float'a veri tipi dönüşümü yapalım.
# Bu dönüşümü astype() metodunu kullanarak yapıyoruz
data['Type 1'] = data['Type 1'].astype('category')
data['Speed'] = data['Speed'].astype('float')

# %%
# Data frame'deki veri tiplerini yeniden inceleyelim
# Görüldüğü üzere Type 1 feature'u altında bulunan bütün veriler önceden object iken şimdi category tipine dönüştü
# Görüldüğü üzere Speed feature'u altında bulunan bütün veriler önceden int64 iken şimdi float64 tipine dönüştü
data.dtypes
# Out:
# #                int64
# Name            object
# Type 1        category
# Type 2          object
# HP               int64
# Attack           int64
# Defense          int64
# Sp. Atk          int64
# Sp. Def          int64
# Speed          float64
# Generation       int64
# Legendary         bool
# dtype: object

# %% [markdown]
# ***
# <a id="24"></a>
# ### MISSING DATA and TESTING WITH ASSERT
# * Missing Data(Kayıp Veri): Eksik veri veya eksik değer şeklinde de ifade edilebilir. Veri setinizdeki bir gözlemde, değişken için hiçbir veri değeri olmamasına denir.
#
#
# * Kayıp verinin kaynağı çok farklı olabilir;
#     * Gerçekten kaybolmuş olabilir. Veri girilirken unutulmuş, gözden kaçmış olabilir.
#     * Bu gözlem için böyle bir değer olmayabilir.
#     * Değer gerçekten bilinmiyor veya tanımlanmıyor olabilir.
#
#
# * Bir *missing data* ile karşılaştığımızı farz edelim. Neler yapabiliriz?
#     * Müdahale etmeden, olduğu gibi bırakabiliriz.
#     * dropna() metodunu kullanarak silebiliriz.
#     * Boş missing value'ları fillna() metodunu kullanarak NaN ile doldurabiliriz.
#     * Mean gibi istatistiksel test değerleri ile missing value kısmını doldurabiliriz.
#
#
# * Assert statement: Python yorumlayıcısı, bir assert ifadesi ile karşılaştığında Python, doğru olduğu umulan, ekteki ifadeyi değerlendirir. İfade yanlışsa, Python bir AssertionError istisnasını oluşturur.

# %%
# Pokemon verisinin içerisinde null değer olup olmadığına bakalım
# Görüldüğü üzere her bir feature'un 800 adet girdisi mevcut.
# Bununla birlikte non-null yani null olmayan verilerin sayısı da belirtilmiş
# Type 2 feature'unun 414 non-null değeri var, o halde 386 null değeri vardır.

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    category
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    float64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), category(1), float64(1), int64(7), object(2)
# memory usage: 64.9+ KB

# %%
# Type 2 feature'nu kontrol edelim
# dropna=False -> Nan değerleri dikkate al

data["Type 2"].value_counts(dropna =False)

# 386 adet Type 2 feature'una sahip olmayan pokemon var, yani NaN değer mevcut
# Dolayısıyla missing value var.
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ice          14
# Rock         14
# Water        14
# Ghost        14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
# NaN değerleri datadan çıkaralım
data1 = data 
data1["Type 2"].dropna(inplace = True)
# inplace = True : çıkarttığımız değerleri data1'e atalım

# %%
# Peki yukarıda yaptığımız işlemler işe yaradı mı?
# assert statement kullanarak kontrol edelim.
# Assert statement:
assert 1==1 # geriye bir şey dönmediği için doğru

# %%
# In order to run all code, we need to make this line comment
# assert 1==2 # return error because it is false

# %%
# assert data['Type 2'].notnull().all() # bu kısım hata verir çünkü bütün NaN değerleri veriden çıkardık
# False olduğunu doğrulayalım
data['Type 2'].notnull().all()
# Out:
# False

# %%
data["Type 2"].fillna('empty',inplace = True)

# %%
assert  data['Type 2'].notnull().all() # Geriye bir şey dönmez çünkü NaN değerleri çıkardık

# %%
#assert statement'ını diğer birçok şeyi kontrol etmek için kullanabiliriz. Örneğin;
assert data.columns[1] == 'Name'
assert data.Speed.dtypes == np.float64

# %% [markdown]
# **Bu bölümde neler öğrendilk?**
# * Diagnose data for cleaning
# * Exploratory data analysis
# * Visual exploratory data analysis
# * Tidy data
# * Pivoting data
# * Concatenating data
# * Data types
# * Missing data and testing with assert

# %% [markdown]
# ***
# <a id="25"></a>
# # 4. PANDAS FOUNDATION

# %% [markdown]
# <a id="26"></a>
# ### PANDAS KÜTÜPHANESİNE GÖZ GEZDİRELİM
# Şu ana kadar Pandas ile alakalı bütün bilgiye tek seferde sahip olmak yerine zaman zaman Pandas'ın bazı temel özelliklerini öğrendik ve bu özellikleri kulladık. Bu noktadan sonra ise Pandas ile alakalı daha derin ve kapsamlı bilgiler üzerinde duracağız.
#
#
# Numpy paketi, veri saklama açısından oldukça hızlı ve etkin bir paket olmakla birlite, farklı türde verileri bir arada kullanılması, verilerden seçim yapma gibi konularda yetersiz kalabilmektedir. *Pandas* paketi, hem yüksek performanslı hem de esnek veri analizi ihtiyacından doğmuş ve bu amaçla geliştirilmiştir.
#
#
# Pandas'ta esas olarak iki temel veri nesnesi/veri tipi mevcuttur. Bunlar;
# * Series
# * DataFrames
#
# Bunlara ek olarak aşağıdaki bilgiler de Pandas paketinin özelliklerindendir.
# * Single Column (Tek Sütun) => Series tipindedir.
# * NaN => Not a Number
# * dataframe.values => DataFrame'in bir sütununu bu şekilde ele aldığımız zaman Numpy'a dönüşür.

# %% [markdown]
# ***
# <a id="27"></a>
# ### BUILDING DATA FRAMES FROM SCRATCH - SIFIRDAN DATA FRAME İNŞA ETMEK
# * Daha önce de yaptığımız gibi *csv* dosyası kullanarak data frame inşa edebiliriz.
# * Aynı zamanda dictionary veri yapısı kullanarak da data frame inşa edebiliriz.
#     * zip() metodu: bu fonksiyon bir tuple listesi döner.
# * Yeni sütun ekleme işlemi yapabiliriz.
# * Broadcasting: Yeni bir sütun yaratıp o sütunun tamamına bir değer atamak.

# %%
# dictionary kullanarak data frame oluşturalım

country = ["Spain", "France"]
population = ["11", "12"]
listLabel = ["country", "population"]
listCol = [country, population]
zipped = list(zip(listLabel, listCol))
dataDict = dict(zipped)
df = pd.DataFrame(dataDict)

# %%
df
# Out:
#   country population
# 0   Spain         11
# 1  France         12

# %%
# Yeni sütun ekleme - Broadcasting'e benzer

df["capital"] = ["madrid","paris"]

# %%
df
# Out:
#   country population capital
# 0   Spain         11  madrid
# 1  France         12   paris

# %%
# Broadcasting

df["income"] = 0 # Bütün bir sütuna broadcasting uygulamak

# %%
df
# Out:
#   country population capital  income
# 0   Spain         11  madrid       0
# 1  France         12   paris       0

# %% [markdown]
# ***
# <a id="28"></a>
# ### VISUAL EXPLORATORY DATA ANALYSIS
# * Plot
# * Subplot
# * Histogram:
#     * bins: number of bins
#     * range(tuble): min and max values of bins
#     * normed(boolean): normalize or not
#     * cumulative(boolean): compute cumulative distribution

# %%
# Pokemon veri setinin Attack, Defense, Speed bilgilerini tek bir plot üzerinde görselleştirebiliriz.

data1 = data.loc[:,["Attack","Defense","Speed"]]
data1.plot()
plt.show()

# %%
# subplots

data1.plot(subplots = True)
plt.show()

# %%
# scatter plot 

data1.plot(kind = "scatter", x="Attack", y = "Defense")
plt.show()

# %%
# hist plot  
data1.plot(kind = "hist", y = "Defense", bins = 50, range= (0,250))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Kümülatif olan ve kümülatif olmayan Histogram subplot'ları

fig, axes = plt.subplots(nrows=2,ncols=1)
data1.plot(kind = "hist", y = "Defense", bins = 50, range = (0,250), ax = axes[0])
data1.plot(kind = "hist", y = "Defense", bins = 50, range = (0,250), ax = axes[1], cumulative = True)
plt.savefig('graph.png')
plt.show()

# %% [markdown]
# ***
# <a id="29"></a>
# ### STATISTICAL EXPLORATORY DATA ANALYSIS
# * Bu kısmı daha önce incelemiştik ancak tekrar edelim.
#     * count: veri içerisindeki girdi sayısı
#     * mean: girdilerin ortalaması
#     * std: standart deviation(standart sapma)
#     * min: minimum girdi
#     * 25%: ilk yüzdelik dilim(firs quantile)
#     * 50%: ortanca değer ya da ikinci yüzdelik dilim(second quantile or median)
#     * 75%: üçüncü yüzdelik dilim(third quantile)
#     * max: maksimum girdi
#
# * `Quantile(Yüzdelik Dilim)` Nedir?
#
#     * 1, 4, 5, 6, 8, 9, 11, 12, 13, 14, 15, 16, 17
#     * Median(medyan), sayı dizisi içerisindeki ortanca değerdir. Bu senaryoda median = 11
#     * `Lower Quartile(İlk Çeyrek/Birinci Kartil)`: Serinin en küçük sayısı(ilk sıradaki sayı) ile medyan arasında kalan sayıların medyanına denir. Bu senaryoda 1-11 arasındaki değerlerin medyanı olan 6 lower quartile'dir.
#     * `Upper Quartile(Üst Çeyrek/Üst Kartil)`: Serinin medyanı ile en büyük sayısı(son sıradaki sayı) arasında kalan sayıların medyanına denir. Bu senaryoda 11-17 arasındaki değerlerin medyanı olan 14 upper quartile'dir.
#
# * `Quantile ve Quartile İlişkisi`
#     * **Lower Quartile = Q1 = %25 Quantile**
#     * **Upper Quartile = Q3 = %75 Quantile**

# %%
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %% [markdown]
# ***
# <a id="30"></a>
# ### INDEXING PANDAS TIME SERIES
# * datetime, tıpkı str, int gibi bir object type'tır.
# * parse_dates(boolean): Üzerinde çalıştığımız tarih verisini ISO 8601 (yyyy-mm-dd hh:mm:ss ) formatına dönüştüren metot.

# %%
# Hatırlarsanız üzerinde çalıştığımız verinin index'leri integer yapısındaydı.
# Pandas Time Series özelliği ise verinin index'lerinin Time Series yapısında olmasıdır.
# Pandas, index'i Time Series yapısında olan data frame'ler için çokça metot geliştirmiştir.
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire   empty  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0   45.0           1      False
# 1   60.0           1      False
# 2   80.0           1      False
# 3   80.0           1      False
# 4   65.0           1      False

# %%
# pokemon veri setinde time yapısında bir veri olmadığı için kendi verimizi oluşturalım.

time_list = ["1992-03-08","1992-04-12"]
print(type(time_list[1])) # Gördüğünüz üzere tarih bilgisi string yapısıdır.
# Ancak biz bu string yapısın datetime object olmasını istiyoruz.

# pd.to_datetime() metodu ile, time_list'i bir datetime object'e dönüştürüyoruz.
datetime_object = pd.to_datetime(time_list)

print(type(datetime_object))
print(f"time_list: {time_list}")
print(f"datetime_object: {datetime_object}")
# Out:
# <class 'str'>
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
# time_list: ['1992-03-08', '1992-04-12']
# datetime_object: DatetimeIndex(['1992-03-08', '1992-04-12'], dtype='datetime64[ns]', freq=None)

# %%
# Interpreter'dan gelecek uyarıları "ignore" ediyoruz.
import warnings
warnings.filterwarnings("ignore")

# Pratik yapmak için pokemon veri setinin ilk 5 verisini alıp içerisine bir time list ekleyelim.
data2 = data.head()
date_list = ["1992-01-10", "1992-02-10", "1992-03-10", "1993-03-15", "1993-03-16"]
datetime_object = pd.to_datetime(date_list)
data2["date"] = datetime_object # datetime_object'i verimize date sütunu altında olacak şekilde ekliyoruz.

# Verimize eklediğimiz date sütununu index olacak şekilde konfigüre ediyoruz
data2 = data2.set_index("date")

# %%
# Yeni data frame'imizi inceleyelim.
data2
# Out:
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# date
# 1992-01-10  1      Bulbasaur  Grass  Poison  45      49       49       65
# 1992-02-10  2        Ivysaur  Grass  Poison  60      62       63       80
# 1992-03-10  3       Venusaur  Grass  Poison  80      82       83      100
# 1993-03-15  4  Mega Venusaur  Grass  Poison  80     100      123      122
# 1993-03-16  5     Charmander   Fire   empty  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# date
# 1992-01-10       65   45.0           1      False
# 1992-02-10       80   60.0           1      False
# 1992-03-10      100   80.0           1      False
# 1993-03-15      120   80.0           1      False
# 1993-03-16       50   65.0           1      False

# %%
# Artık, date index üzerinden istediğimiz veriyi inceleyebiliriz.
data2.loc["1993-03-16"]
# Out:
# #                      5
# Name          Charmander
# Type 1              Fire
# Type 2             empty
# HP                    39
# Attack                52
# Defense               43
# Sp. Atk               60
# Sp. Def               50
# Speed               65.0
# Generation             1
# Legendary          False
# Name: 1993-03-16 00:00:00, dtype: object

# %%
# datetime nesneleri üze<rinde slicing yapmak mümkündür
data2.loc["1992-03-10":"1993-03-16"]
# Out:
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# date
# 1992-03-10  3       Venusaur  Grass  Poison  80      82       83      100
# 1993-03-15  4  Mega Venusaur  Grass  Poison  80     100      123      122
# 1993-03-16  5     Charmander   Fire   empty  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# date
# 1992-03-10      100   80.0           1      False
# 1993-03-15      120   80.0           1      False
# 1993-03-16       50   65.0           1      False

# %% [markdown]
# ***
# <a id="31"></a>
# ### RESAMPLING PANDAS TIME SERIES
# * Resampling: Popülasyon hakkında çıkarımlar yapabilmek için bir veri setinden yerine koyarak (sampling with replacement) tekrar tekrar aynı büyüklükte örneklemler oluşturmaya yeniden örnekleme (resampling) denir. Bu yöntemler sayesinde örneklemlerin belirsizliği ve değişkenliği ile ilgili daha iyi fikir elde edilebilir.
#     * Resampling yaparken "Ay" ve "Yıl" bazı alınabilir. Ay için resample("M"), yıl için ise resample("A") kullanılır.
# * Downsampling: date-time object yapısındaki dataframe satırlarını günlük değişimden haftalık değişime doğru biraz daha seyrek frekansa indirmemizi sağlayan yöntem.
# * Upsampling: date-time object yapısındaki dataframe satırlarının sıklığı arttırmamızı sağlayan yöntem. Örneğin günlük değişimden saatlik değişime çevrim gibi.
# * Interpolate: 'Linear', "time" veya 'index' gibi farklı teknikleri ya da verileri baz alarak NaN değerleri düzenlemek ve eksik verileri doldurmak için kullandığımuz yöntem. Bahsedilen paratmetreler ile birlikte başka birçok çok parametre baz alınabilir. Bu yönteme dair bilgi almak için:
#     * https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.interpolate.html

# %%
# data2 data frame'i üzerinde yıl verisini baz alarak resampling yapalım.
# Burada yıllara göre feature'ların ortalama değerlerini inceliyoruz.
data2.resample("A").mean()
# Out:
#               #         HP     Attack  Defense    Sp. Atk    Sp. Def  \
# date
# 1992-12-31  2.0  61.666667  64.333333     65.0  81.666667  81.666667
# 1993-12-31  4.5  59.500000  76.000000     83.0  91.000000  85.000000
#
#                 Speed  Generation  Legendary
# date
# 1992-12-31  61.666667         1.0        0.0
# 1993-12-31  72.500000         1.0        0.0

# %%
# Şimdi de aylara göre resampling yapalım
data2.resample("M").mean()
# Görüldüğü üzere yer yer NaN veriler mevcut, bunun nedeni ise data2'de bazı aylara ait verilerin mevcut olmamasıdır.
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# date
# 1992-01-31  1.0  45.0    49.0     49.0     65.0     65.0   45.0         1.0
# 1992-02-29  2.0  60.0    62.0     63.0     80.0     80.0   60.0         1.0
# 1992-03-31  3.0  80.0    82.0     83.0    100.0    100.0   80.0         1.0
# 1992-04-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-05-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-06-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-07-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-08-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-09-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-10-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-11-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# ...

# %%
# Gerçek hayatın gerçek verileri ile çalışırken boş verileri doldurmamız gerekebilir.
# Bunu gerçekleştirmek için "interpolate" yöntemini kullanırız.
# Interpolate yöntemi ile yalnızca nümerik veriler doldurulabilir. 
# İlk değerden itibaren interpolate işlemini başlatalım.
# Burada interpolate yöntemini linear parametresi kullanarak gerçekleştiriyoruz
data2.resample("MS").first().interpolate("ffill")
# Out:
#               #           Name Type 1  Type 2    HP  Attack  Defense  Sp. Atk  \
# date
# 1992-01-01  1.0      Bulbasaur  Grass  Poison  45.0    49.0     49.0     65.0
# 1992-02-01  2.0        Ivysaur  Grass  Poison  60.0    62.0     63.0     80.0
# 1992-03-01  3.0       Venusaur  Grass  Poison  80.0    82.0     83.0    100.0
# 1992-04-01  3.0       Venusaur  Grass  Poison  80.0    82.0     83.0    100.0
# 1992-05-01  3.0       Venusaur  Grass  Poison  80.0    82.0     83.0    100.0
# 1992-06-01  3.0       Venusaur  Grass  Poison  80.0    82.0     83.0    100.0
# 1992-07-01  3.0       Venusaur  Grass  Poison  80.0    82.0     83.0    100.0
# 1992-08-01  3.0       Venusaur  Grass  Poison  80.0    82.0     83.0    100.0
# 1992-09-01  3.0       Venusaur  Grass  Poison  80.0    82.0     83.0    100.0
# 1992-10-01  3.0       Venusaur  Grass  Poison  80.0    82.0     83.0    100.0
# 1992-11-01  3.0       Venusaur  Grass  Poison  80.0    82.0     83.0    100.0
# ...

# %%
# İlk değerden itibaren değil de ortalamasını alarak linear parametresi ile birlikte interpolate işlemi yapabiliriz.
data2.resample("M").mean().interpolate("linear")
# Out:
#                 #         HP  Attack  Defense  Sp. Atk  Sp. Def   Speed  \
# date
# 1992-01-31  1.000  45.000000    49.0     49.0    65.00    65.00  45.000
# 1992-02-29  2.000  60.000000    62.0     63.0    80.00    80.00  60.000
# 1992-03-31  3.000  80.000000    82.0     83.0   100.00   100.00  80.000
# 1992-04-30  3.125  78.291667    81.5     83.0    99.25    98.75  79.375
# 1992-05-31  3.250  76.583333    81.0     83.0    98.50    97.50  78.750
# 1992-06-30  3.375  74.875000    80.5     83.0    97.75    96.25  78.125
# 1992-07-31  3.500  73.166667    80.0     83.0    97.00    95.00  77.500
# 1992-08-31  3.625  71.458333    79.5     83.0    96.25    93.75  76.875
# 1992-09-30  3.750  69.750000    79.0     83.0    95.50    92.50  76.250
# 1992-10-31  3.875  68.041667    78.5     83.0    94.75    91.25  75.625
# 1992-11-30  4.000  66.333333    78.0     83.0    94.00    90.00  75.000
# 1992-12-31  4.125  64.625000    77.5     83.0    93.25    88.75  74.375
# ...

# %% [markdown]
# ***
# <a id="32"></a>
# # MANIPULATING DATA FRAMES WITH PANDAS - PANDAS KULLANARAK DATAFRAME MANİPÜLASYONU

# %% [markdown]
# <a id="33"></a>
# ### INDEXING DATA FRAMES - DATAFRAME İNDEKSLEME
# * Dataframe indeksleme işlemi için birden fazla yöntem mevcuttur. Bunlar;
#     * Köşeli parantez - [ ] kullanarak indeksleme,
#     * Sütun niteliğini ve satır etiketini kullanarak indeksleme,
#     * *loc* accessor kullanarak indeksleme,
#     * Belirli sütunları seçerek indeksleme.

# %%
# Kullanacağımız veriyi import edelim.
pokemon_dataset = pd.read_csv('datasets/pokemon.csv')

# %%
# Verisetimizin index sütununu # olacak şekilde belirliyoruz.
pokemon_dataset = pokemon_dataset.set_index("#")

# %%
# Verisetimizi inceleyelim
pokemon_dataset.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2        Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3       Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# 5     Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary
# #
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False
# 5           1      False

# %%
# Köşeli parantez kullanarak indeksleme yapalım
# Görüldüğü üzere bu yöntemede öncelikle sütun adını belirtiyoruz.
# HP sütununun 1 satırı gibi düşünebiliriz
pokemon_dataset["HP"][1]
# Out:
# 45

# %%
# Sütun niteliğini ve satır etiketini kullanarak indeksleme yapalım
# Görüldüğü üzere bu yöntemede öncelikle sütun adını belirtiyoruz.
# HP sütununun 1 satırı gibi düşünebiliriz
pokemon_dataset.HP[1]
# Out:
# 45

# %%
# loc accessor kullanarak indeksleme yapalım
# Görüldüğü üzere bu yöntemede öncelikle satır adını belirtiyoruz.
# 1. satırdaki HP sütununun değeri gibi düşünebiliriz.
pokemon_dataset.loc[1,["HP"]]
# Out:
# HP    45
# Name: 1, dtype: object

# %%
# Belirli sütunları seçerek indeksleme yapalım
pokemon_dataset[["HP","Attack"]]
# Out:
#      HP  Attack
# #
# 1    45      49
# 2    60      62
# 3    80      82
# 4    80     100
# 5    39      52
# ..   ..     ...
# 796  50     100
# 797  50     160
# 798  80     110
# 799  80     160
# 800  80     110
#
# [800 rows x 2 columns]

# %% [markdown]
# ***
# <a id="34"></a>
# ### SLICING DATA FRAME - VERİSETİNİ DİLİMLEME İŞLEMİ
# * Sütunları seçerken bazı noktalara dikkat etmemiz gerekiyor. Sütun seçiminde kullandığımız yönteme göre aşağıdaki veri tiplerinde değişkenler yaratmış oluruz:
#     * Series
#     * Dataframes
# * Dilimleme ve indeksleme yöntemi ile Series tipindeki bir değişkeni manipüle etme işlemi gerçekleştirebiliriz.
# * Reverse slicing
# * From something to end

# %%
# veriseti["sütunadı"] -> Series tipinde değişken yaratır.
# veriseti[["sütunadı"]] -> Dataframe tipinde değişken yaratır.

print(type(data["HP"]))     # series
print(type(data[["HP"]]))   # dataframes
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# Dilimleme ve indeksleme yöntemi ile Series tipindeki bir değişkeni manipüle etme işlemi
# 1:10 -> Satır bazında manipülasyon
# "HP":"Defense" -> Sütun bazında manipülasyon

data.loc[1:10,"HP":"Defense"]
# Out:
#     HP  Attack  Defense
# 1   60      62       63
# 2   80      82       83
# 3   80     100      123
# 4   39      52       43
# 5   58      64       58
# 6   78      84       78
# 7   78     130      111
# 8   78     104       78
# 9   44      48       65
# 10  59      63       80

# %%
# Reverse Slicing - Tersine Dilimleme
data.loc[10:1:-1,"HP":"Defense"]
# Out:
#     HP  Attack  Defense
# 10  59      63       80
# 9   44      48       65
# 8   78     104       78
# 7   78     130      111
# 6   78      84       78
# 5   58      64       58
# 4   39      52       43
# 3   80     100      123
# 2   80      82       83
# 1   60      62       63

# %%
# Son sütuna kadar sütun seçme işlemi
data.loc[1:10,"Speed":]
# Out:
#     Speed  Generation  Legendary
# 1    60.0           1      False
# 2    80.0           1      False
# 3    80.0           1      False
# 4    65.0           1      False
# 5    80.0           1      False
# 6   100.0           1      False
# 7   100.0           1      False
# 8   100.0           1      False
# 9    43.0           1      False
# 10   58.0           1      False

# %% [markdown]
# <a id="35"></a>
# ### FILTERING DATAFRAMES - DATAFRAME FİLTRELEME
# * Bu işlemin belirli çeşitleri mevcuttur. Bunlar;
#     * Boolean veri tipinde değerlere sahip Series değişkenler oluşturma,
#     * Filtreleme yöntemlerini birleştirme,
#     * Diğer sütunlara göre seçili sütunu filtreleme.

# %%
# Boolean veri tipinde değerlere sahip Series değişkenler oluşturma işlemi

boolean = data.HP > 200
data[boolean]
# Out:
#        #     Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121  122  Chansey  Normal  empty  250       5        5       35      105
# 261  262  Blissey  Normal  empty  255      10       10       75      135
#
#      Speed  Generation  Legendary
# 121   50.0           1      False
# 261   55.0           2      False

# %%
# Yukarıdaki işlemi aşağıdaki şekilde de gerçekleştirmek mümkündür

boolean = data["HP"] > 200
data[boolean]
# Out:
#        #     Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121  122  Chansey  Normal  empty  250       5        5       35      105
# 261  262  Blissey  Normal  empty  255      10       10       75      135
#
#      Speed  Generation  Legendary
# 121   50.0           1      False
# 261   55.0           2      False

# %%
# Filtreleri birleştirme işlemi
# Aşağıdaki işlemde HP feature'u 150'nin üzerinde olan ve Speed feature'u 35'in
# üzerinde olan sample'lar filtreleniyor.
first_filter = data["HP"] > 150
second_filter = data["Speed"] > 35
data[first_filter & second_filter]
# Out:
#        #       Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121  122    Chansey  Normal  empty  250       5        5       35      105
# 261  262    Blissey  Normal  empty  255      10       10       75      135
# 351  352    Wailord   Water  empty  170      90       45       90       45
# 655  656  Alomomola   Water  empty  165      75       80       40       45
#
#      Speed  Generation  Legendary
# 121   50.0           1      False
# 261   55.0           2      False
# 351   60.0           3      False
# 655   65.0           5      False

# %%
# Diğer sütunlara göre seçili sütunu filtreleme işlemi
# Speed değeri 15'den küçük olan pokemonların HP değerlerini görelim.
data["HP"][data["Speed"]<15]
# Out:
# 230     20
# 359     45
# 486     50
# 495    135
# 658     44
# Name: HP, dtype: int64

# %% [markdown]
# ***
# <a id="36"></a>
# ### TRANSFORMING DATA - VERİ DÖNÜŞÜMÜ
# * Bilinen python fonksiyonları kullanılarak gerçekleştirilir.
# * Lambda fonksiyonu kullanılır.
# * Diğer sütunları kullanarak sütun tanımlama işlemi gerçekleştirilir.

# %%
# Bilinen python fonksiyonları kullanmak.
# apply() metodu sayesinde ürettiğimiz fonksiyonu veriseti üzerinde kullanabiliyoruz.
def div(n):
    return n/2
data["HP"].apply(div)
# Out:
# 0      22.5
# 1      30.0
# 2      40.0
# 3      40.0
# 4      19.5
#        ...
# 795    25.0
# 796    25.0
# 797    40.0
# 798    40.0
# 799    40.0
# Name: HP, Length: 800, dtype: float64

# %%
# Lambda fonksiyonu kullanarak işlem yapmak.
data["HP"].apply(lambda n : n/2)
# Out:
# 0      22.5
# 1      30.0
# 2      40.0
# 3      40.0
# 4      19.5
#        ...
# 795    25.0
# 796    25.0
# 797    40.0
# 798    40.0
# 799    40.0
# Name: HP, Length: 800, dtype: float64

# %%
# Diğer sütunları kullanarak sütun tanımlama işlemi gerçekleştirmek
# Yeni bir sütun tanımlarken diğer sütunları kullanıyoruz.
data["total_power"] = data["Attack"] + data["Defense"]
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire   empty  39      52       43       60       50
#
#    Speed  Generation  Legendary  total_power
# 0   45.0           1      False           98
# 1   60.0           1      False          125
# 2   80.0           1      False          165
# 3   80.0           1      False          223
# 4   65.0           1      False           95

# %% [markdown]
# <a id="37"></a>
# ### INDEX OBJECTS AND LABELED DATA - NESNELERİ VE ETİKETLİ VERİLERİ İNDEKSLEME
# * index: verilerin sıra numarasını belirten değişken

# %%
# Verisetimizin indeks ismine bakalım
print(data.index.name)
# Out:
# None

# %%
# Şimdi de indeks ismini değiştirelim
data.index.name = "index_name"
data.head()
# Out:
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# index_name
# 0           1      Bulbasaur  Grass  Poison  45      49       49       65
# 1           2        Ivysaur  Grass  Poison  60      62       63       80
# 2           3       Venusaur  Grass  Poison  80      82       83      100
# 3           4  Mega Venusaur  Grass  Poison  80     100      123      122
# 4           5     Charmander   Fire   empty  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary  total_power
# index_name
# 0                65   45.0           1      False           98
# 1                80   60.0           1      False          125
# 2               100   80.0           1      False          165
# 3               120   80.0           1      False          223
# 4                50   65.0           1      False           95

# %%
# Indeks sütununu yapılandıralım
# Indeks sütununu yapılandırmak istiyorsak tamamını değiştirmemiz gerekir.
data.head()
# Öncelikle "data" dataframe'ini "data3" dataframe'ine kopyalayalım.
data3 = data.copy()
# Örnek olması için indeksi 100'den başlatalım.
data3.index = range(100,900,1)
data3.head()
# Out:
#      #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 100  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 101  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 102  3       Venusaur  Grass  Poison  80      82       83      100      100
# 103  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 104  5     Charmander   Fire   empty  39      52       43       60       50
#
#      Speed  Generation  Legendary  total_power
# 100   45.0           1      False           98
# 101   60.0           1      False          125
# 102   80.0           1      False          165
# 103   80.0           1      False          223
# 104   65.0           1      False           95

# %%
# Aşağıdaki ifadeleri kullanarak dataframe üzerindeki herhangi bir sütunu indeks olarak belirleyebiliriz.

# data= data.set_index("#")
# data.index = data["#"]

# %% [markdown]
# ***
# <a id="38"></a>
# ### HIERARCHICAL INDEXING - HİYERARŞİK İNDEKSLEME
# * Birden fazla indeks seçimi yapmak mümkündür.

# %%
# Temiz bir başlangıç yapmak adına pokemon.csv dosyasını yeniden import edelim.
data = pd.read_csv('datasets/pokemon.csv')

# %%
data.head()
# Görüldüğü üzere dataframe'in bir indeks sütunu mevcut.
# Ancak biz birden fazla indeks sütunu belirlemek istiyoruz.
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
# Yeni indeksleri aşağıdaki sıfatlarda tanımlıyoruz:
    # Type 1 : Outer Index (Dış İndeks)
    # Type 2 : Inner Index (İç İndeks)
    
data1 = data.set_index(["Type 1","Type 2"]) 
data1.head(100)
# Out:
#                  #           Name   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1 Type 2
# Grass  Poison    1      Bulbasaur   45      49       49       65       65
#        Poison    2        Ivysaur   60      62       63       80       80
#        Poison    3       Venusaur   80      82       83      100      100
#        Poison    4  Mega Venusaur   80     100      123      122      120
# Fire   NaN       5     Charmander   39      52       43       60       50
# ...            ...            ...  ...     ...      ...      ...      ...
# Poison NaN      96         Grimer   80      80       50       40       50
#        NaN      97            Muk  105     105       75       65      100
# Water  NaN      98       Shellder   30      65      100       45       25
#        Ice      99       Cloyster   50      95      180       85       45
# Ghost  Poison  100         Gastly   30      35       30      100       35
#
#                Speed  Generation  Legendary
# Type 1 Type 2
# ...

# %%
# Peki biz bu yöntemi kullanarak neyi amaçlıyoruz?
# Şöyle bir örnek yapalım: Type 1 indeksi içindeki Type 2'ye göre bir dataframe oluşturalım.
# Fire(Type 1) tipindeki pokemonlardan hangileri uçuyor(Type 2)?
data1.loc["Fire","Flying"]
# Out:
#                  #              Name   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1 Type 2
# Fire   Flying    7         Charizard   78      84       78      109       85
#        Flying    9  Mega Charizard Y   78     104       78      159      115
#        Flying  159           Moltres   90     100       90      125       85
#        Flying  271             Ho-oh  106     130       90      110      154
#        Flying  731       Fletchinder   62      73       55       56       52
#        Flying  732        Talonflame   78      81       71       74       69
#
#                Speed  Generation  Legendary
# Type 1 Type 2
# Fire   Flying    100           1      False
#        Flying    100           1      False
#        Flying     90           1       True
#        Flying     90           2       True
#        Flying     84           6      False
#        Flying    126           6      False

# %% [markdown]
# <a id="39"></a>
# ### PIVOTING DATAFRAMES - VERİ SETİNİ DÖNDÜRME
# * Pivoting: yeniden şekillendirme tekniği.
# * Yani halihazıda feature olarak kullandığımız veriler pivotting ile birlikte sample'a dönüşür, kısacası sütunlar satır olur.

# %%
# Pivotting yöntemini incelemek için bir veri oluşturalım.
dic = {"treatment":["A","A","B","B"],"gender":["F","M","F","M"],"response":[10,45,5,9],"age":[15,4,72,65]}
df = pd.DataFrame(dic)
df
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
# Pivoting yöntemini uygulayalım.
df.pivot(index="treatment",columns = "gender",values="response")
# Out:
# gender      F   M
# treatment
# A          10  45
# B           5   9

# %% [markdown]
# <a id="40"></a>
# ### STACKING AND UNSTACKING DATAFRAME - DATAFRAME İSTİFLEME VE İSTİFTEN ÇIKARMA
# * Bu yöntem birden fazla etikete sahip indeksler ile çalışabilmemizi sağlar.
# * Level: İstiften çıkarışmış indeksin pozisyonu.
# * Swaplevel: Inner ve Outer seviyesindeki indekslerin pozisyonunu değiştirme.

# %%
df1 = df.set_index(["treatment","gender"])

# %%
df1
# Şimdi bu dataframe'i istiften çıkaralım.
# Out:
#                   response  age
# treatment gender
# A         F             10   15
#           M             45    4
# B         F              5   72
#           M              9   65

# %%
df1.unstack(level=0)
# Out:
#           response    age
# treatment        A  B   A   B
# gender
# F               10  5  15  72
# M               45  9   4  65

# %%
df1.unstack(level=1)
# Out:
#           response     age
# gender           F   M   F   M
# treatment
# A               10  45  15   4
# B                5   9  72  65

# %%
# Datafame'in Inner ve Outer indeks pozisyonlarını değiştirelim.
df2 = df1.swaplevel(0,1)

# %%
df2
# Out:
#                   response  age
# gender treatment
# F      A                10   15
# M      A                45    4
# F      B                 5   72
# M      B                 9   65

# %% [markdown]
# <a id="41"></a>
# ### MELTING DATA FRAMES
# * Pivotting işleminin tam tersi işlemine sahiptir.

# %%
# Dataframe'imimizi görelim.
df
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
# df.pivot(index="treatment",columns = "gender",values="response")
pd.melt(df,id_vars="treatment",value_vars=["age","response"])
# Out:
#   treatment  variable  value
# 0         A       age     15
# 1         A       age      4
# 2         B       age     72
# 3         B       age     65
# 4         A  response     10
# 5         A  response     45
# 6         B  response      5
# 7         B  response      9

# %% [markdown]
# <a id="42"></a>
# ### CATEGORICALS AND GROUPBY

# %%
# Dataframe'imimizi görelim.
df
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
# treatment feature'una göre diğer feature'ları gruplandıralım ve ortalamalarını alalım
df.groupby("treatment").mean()
# Out:
#            response   age
# treatment
# A              27.5   9.5
# B               7.0  68.5

# %%
# Yalnızca bir feature seçmek mümkündür.
df.groupby("treatment").age.max()
# Out:
# treatment
# A    15
# B    72
# Name: age, dtype: int64

# %%
# Bununla birlikte birden fazla feature üzerinden groupby() metodunu çalıştırmak da mümkündür.
df.groupby("treatment")[["age","response"]].min()
# Out:
#            age  response
# treatment
# A            4        10
# B           65         5

# %%
df.info()
# Görüldüğü üzere gender feature'u bir object'tir.
# Bununla birlikte groupby() metodunu kullanarak category verisine dönüşüm sağlayabiliriz.
# Çünkü category tipindeki bir veri daha az bellek harcar kaynağına ihtiyaç duyar.
# İşlemlerin hızlı gerçekleşmesini salar.
df["gender"] = df["gender"].astype("category")
df["treatment"] = df["treatment"].astype("category")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   treatment  4 non-null      object
#  1   gender     4 non-null      object
#  2   response   4 non-null      int64
#  3   age        4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   treatment  4 non-null      category
#  1   gender     4 non-null      category
#  2   response   4 non-null      int64
#  3   age        4 non-null      int64
# dtypes: category(2), int64(2)
# memory usage: 448.0 bytes
